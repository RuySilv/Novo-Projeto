# %% [markdown]
# # Novo Dataset ICD
# ---

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_palette('Set2')

# %%
covid = pd.read_csv('C:\\Users\\Ruy\\Documents\\Exercicios ICD\\covid19.csv')
covid
covid.drop(columns=['New cases',"New deaths","New recovered","1 week change"])
# Out:
#          Country/Region  Confirmed  Deaths  Recovered  Active  \
# 0           Afghanistan      36263    1269      25198    9796
# 1               Albania       4880     144       2745    1991
# 2               Algeria      27973    1163      18837    7973
# 3               Andorra        907      52        803      52
# 4                Angola        950      41        242     667
# ..                  ...        ...     ...        ...     ...
# 182  West Bank and Gaza      10621      78       3752    6791
# 183      Western Sahara         10       1          8       1
# 184               Yemen       1691     483        833     375
# 185              Zambia       4552     140       2815    1597
# 186            Zimbabwe       2704      36        542    2126
#
#      Deaths / 100 Cases  Recovered / 100 Cases  Deaths / 100 Recovered  \
# 0                  3.50                  69.49                    5.04
# 1                  2.95                  56.25                    5.25
# ...

# %% [markdown]
# # Médias
# ---

# %%
#Média(Casos Confirmados)
Medconfirmado = covid['Confirmed'].mean()
print("A média de casos confirmados é: %.2f" %Medconfirmado)

#Média(Mortes)
Medmorte = covid['Deaths'].mean()
print("A média de mortes é: %.2f" %Medmorte)

#Média(Recuperados)
Medrec = covid["Recovered"].mean()
print("A média de recuperados é: %.2f" %Medrec)

#Média(Casos Ativos)
Medact = covid["Active"].mean()
print("A média de recuperados é: %.2f" %Medact)

#Média(Morte para cada 100 casos)
Medmp100 = covid["Deaths / 100 Cases"].mean()
print("A média de Mortes a cada 100 casos é: %.2f" %Medmp100)

#Média(Recuperados para cada 100 casos)
Medrecp100 = covid["Recovered / 100 Cases"].mean()
print("A média de Recuperados a cada 100 casos é: %.2f" %Medrecp100)

#Média (Confirmados na última semana)
Medlw = covid["Confirmed last week"].mean()
print("A média de confirmados na última semana é: %.2f" %Medlw)

#Média(% de aumentos em uma semana)
Medincrease = covid["1 week % increase"].mean()
print("A média de %% de aumentos em uma semana é: %.2f" %Medincrease)
# Out:
# A média de casos confirmados é: 88130.94
# A média de mortes é: 3497.52
# A média de recuperados é: 50631.48
# A média de recuperados é: 34001.94
# A média de Mortes a cada 100 casos é: 3.02
# A média de Recuperados a cada 100 casos é: 64.82
# A média de confirmados na última semana é: 78682.48
# A média de % de aumentos em uma semana é: 13.61

# %% [markdown]
# # Medianas
# ---

# %%
# Mediana(Confirmed)
Mediana_Confirmed = covid["Confirmed"].median()
print("A Mediana de confirmados é: %.2f" %Mediana_Confirmed)

# Médiana(Deaths)
Mediana_Deaths = covid["Deaths"].median()
print("A Mediana das mortes é: %.2f" %Mediana_Deaths)

# Médiana(Recovered)
Mediana_Recovered = covid["Recovered"].median()
print("A Mediana dos recuperados é: %.2f" %Mediana_Recovered)

# Médiana(Active)
Mediana_Active = covid["Active"].median()
print("A Mediana dos casos ativos é: %.2f" %Mediana_Active)

# Médiana(Deaths/100 Cases)
Mediana_Deaths_100 = covid["Deaths / 100 Cases"].median()
print("A Mediana das mortes a cada 100 casos é: %.2f" %Mediana_Deaths_100)

# Médiana(Recovered/100 Cases)
Mediana_Recovered_100 = covid["Recovered / 100 Cases"].median()
print("A Mediana dos recuperados a cada 100 casos é: %.2f" %Mediana_Recovered_100)

# Médiana(Deaths/100 Recovered)
Mediana_Deaths_100 = covid["Deaths / 100 Recovered"].median()
print("A Mediana de mortes a cada 100 casos é: %.2f" %Mediana_Deaths_100)

# Médiana(Confirmed last week)
Mediana_Confirmed_last = covid["Confirmed last week"].median()
print("A Mediana de confirmados na última semana é: %.2f" %Mediana_Confirmed_last)

# Médiana(1 week % increase)
Mediana_1_week = covid["1 week % increase"].median()
print("A Mediana de aumentos em uma semana é: %.2f" %Mediana_1_week)
# Out:
# A Mediana de confirmados é: 5059.00
# A Mediana das mortes é: 108.00
# A Mediana dos recuperados é: 2815.00
# A Mediana dos casos ativos é: 1600.00
# A Mediana das mortes a cada 100 casos é: 2.15
# A Mediana dos recuperados a cada 100 casos é: 71.32
# A Mediana de mortes a cada 100 casos é: 3.62
# A Mediana de confirmados na última semana é: 5020.00
# A Mediana de aumentos em uma semana é: 6.89

# %% [markdown]
# # Modas
#  ----

# %%
#Moda(Casos Confirmados)
#Modconfirmado = covid['Confirmed'].mode()
#print("A Moda de casos confirmados é: %.2f" %Modconfirmado)
#Não foi possível realizar a Moda da coluna Casos Confirmados.

#Moda(Mortes)
Modmorte = covid['Deaths'].mode()
print("A Moda de mortes é: %.2f" %Modmorte)

#Moda(Recuperados)
Modrec = covid["Recovered"].mode()
print("A Moda de recuperados é: %.2f" %Modrec)

#Moda(Casos Ativos)
Modact = covid["Active"].mode()
print("A Moda de recuperados é: %.2f" %Modact)

#Moda(Morte para cada 100 casos)
Modmp100 = covid["Deaths / 100 Cases"].mode()
print("A Moda de Mortes a cada 100 casos é: %.2f" %Modmp100)

#Moda(Recuperados para cada 100 casos)
Modrecp100 = covid["Recovered / 100 Cases"].mode()
print("A Moda de Recuperados a cada 100 casos é: %.2f" %Modrecp100)

#Moda (Confirmados na última semana)
#Modlw = covid["Confirmed last week"].mode()
#print("A Moda de confirmados na última semana é: %.2f" %Modlw)
#Também não foi possível "cannot convert the series to <class 'float'>"
#Moda(% de aumentos em uma semana)
Modincrease = covid["1 week % increase"].mode()
print("A Moda de %% de aumentos em uma semana é: %.2f" %Modincrease)
# Out:
# A Moda de mortes é: 0.00
# A Moda de recuperados é: 0.00
# A Moda de recuperados é: 0.00
# A Moda de Mortes a cada 100 casos é: 0.00
# A Moda de Recuperados a cada 100 casos é: 0.00
# A Moda de % de aumentos em uma semana é: 0.00

# %% [markdown]
# # Variancias
# ---

# %%
# Variancia(Confirmed)
Variancia_Confirmed = covid["Confirmed"].var()
print("A Variancia de confirmados é: %.2f" %Variancia_Confirmed)

# Variancia(Deaths)
Variancia_Deaths = covid["Deaths"].var()
print("A Variancia das mortes é: %.2f" %Variancia_Deaths)

# Variancia(Recovered)
Variancia_Recovered = covid["Recovered"].var()
print("A Variancia dos recuperados é: %.2f" %Variancia_Recovered)

# Variancia(Active)
Variancia_Active = covid["Active"].var()
print("A Variancia dos casos ativos é: %.2f" %Variancia_Active)

# Variancia(Deaths/100 Cases)
Variancia_Deaths_100 = covid["Deaths / 100 Cases"].var()
print("A Variancia das mortes a cada 100 casos é: %.2f" %Variancia_Deaths_100)

# Variancia(Recovered/100 Cases)
Variancia_Recovered_100 = covid["Recovered / 100 Cases"].var()
print("A Variancia dos recuperados a cada 100 casos é: %.2f" %Variancia_Recovered_100)

# Variancia(Deaths/100 Recovered)
Variancia_Deaths_100 = covid["Deaths / 100 Recovered"].var()
print("A Variancia de mortes a cada 100 casos é: %.2f" %Variancia_Deaths_100)

# Variancia(Confirmed last week)
Variancia_Confirmed_last = covid["Confirmed last week"].var()
print("A Variancia de confirmados na última semana é: %.2f" %Variancia_Confirmed_last)

# Variancia(1 week % increase)
Variancia_1_week = covid["1 week % increase"].var()
print("A Variancia de aumentos em uma semana é: %.2f" %Variancia_1_week)
# Out:
# A Variancia de confirmados é: 146933198040.89
# A Variancia das mortes é: 198810069.99
# A Variancia dos recuperados é: 36171547479.73
# A Variancia dos casos ativos é: 45508056245.30
# A Variancia das mortes a cada 100 casos é: 11.93
# A Variancia dos recuperados a cada 100 casos é: 691.04
# A Variancia de mortes a cada 100 casos é: nan
# A Variancia de confirmados na última semana é: 114429080257.84
# A Variancia de aumentos em uma semana é: 600.73

# %% [markdown]
# # Desvio Padrão
# ---

# %%
#Desvio Padrão(Casos Confirmados)
DPconfirmado = covid['Confirmed'].std()
print("O Desvio Padrão de casos confirmados é: %.2f" %DPconfirmado)

#Desvio Padrão(Mortes)
DPmorte = covid['Deaths'].std()
print("O Desvio Padrão de mortes é: %.2f" %DPmorte)

#Desvio Padrão(Recuperados)
DPdrec = covid["Recovered"].std()
print("O Desvio Padrão de recuperados é: %.2f" %DPdrec)

#Desvio Padrão(Casos Ativos)
DPact = covid["Active"].std()
print("O Desvio Padrão de recuperados é: %.2f" %DPact)

#Desvio Padrão(Morte para cada 100 casos)
DPmp100 = covid["Deaths / 100 Cases"].std()
print("O Desvio Padrão de Mortes a cada 100 casos é: %.2f" %DPmp100)

#Desvio Padrão(Recuperados para cada 100 casos)
DPrecp100 = covid["Recovered / 100 Cases"].std()
print("O Desvio Padrão de Recuperados a cada 100 casos é: %.2f" %DPrecp100)

#Desvio Padrão(Confirmados na última semana)
DPlw = covid["Confirmed last week"].std()
print("O Desvio Padrão de confirmados na última semana é: %.2f" %DPlw)

#Desvio Padrão(% de aumentos em uma semana)
DPincrease = covid["1 week % increase"].std()
print("O Desvio Padrão da %% de aumentos em uma semana é: %.2f" %DPincrease)
# Out:
# O Desvio Padrão de casos confirmados é: 383318.66
# O Desvio Padrão de mortes é: 14100.00
# O Desvio Padrão de recuperados é: 190188.19
# O Desvio Padrão de recuperados é: 213326.17
# O Desvio Padrão de Mortes a cada 100 casos é: 3.45
# O Desvio Padrão de Recuperados a cada 100 casos é: 26.29
# O Desvio Padrão de confirmados na última semana é: 338273.68
# O Desvio Padrão da % de aumentos em uma semana é: 24.51

# %% [markdown]
# # Desvio Absoluto
# ---

# %%
#Desvio Absoluto(Casos Confirmados)
Desvioconfirmado = covid['Confirmed'].mad()
print("O Desvio Absoluto de casos confirmados é: %.2f" %Desvioconfirmado)

#Desvio Absoluto(Mortes)
Desviomorte = covid['Deaths'].mad()
print("O Desvio Absoluto de mortes é: %.2f" %Desviomorte)

#Desvio Absoluto(Recuperados)
Desviodrec = covid["Recovered"].mad()
print("O Desvio Absoluto de recuperados é: %.2f" %Desviodrec)

#Desvio Absoluto(Casos Ativos)
Desvioact = covid["Active"].mad()
print("O Desvio Absoluto de recuperados é: %.2f" %Desvioact)

#Desvio Absoluto(Morte para cada 100 casos)
Desviomp100 = covid["Deaths / 100 Cases"].mad()
print("O Desvio Absoluto de Mortes a cada 100 casos é: %.2f" %Desviomp100)

#Desvio Absoluto(Recuperados para cada 100 casos)
Desviorecp100 = covid["Recovered / 100 Cases"].mad()
print("O Desvio Absoluto de Recuperados a cada 100 casos é: %.2f" %Desviorecp100)

#Desvio Absoluto(Confirmados na última semana)
Desviolw = covid["Confirmed last week"].mad()
print("O Desvio Absoluto de confirmados na última semana é: %.2f" %Desviolw)

#Desvio Absoluto(% de aumentos em uma semana)
Desvioincrease = covid["1 week % increase"].mad()
print("O Desvio Absoluto da %% de aumentos em uma semana é: %.2f" %Desvioincrease)
# Out:
# O Desvio Absoluto de casos confirmados é: 127333.32
# O Desvio Absoluto de mortes é: 5452.17
# O Desvio Absoluto de recuperados é: 74426.83
# O Desvio Absoluto de recuperados é: 52024.71
# O Desvio Absoluto de Mortes a cada 100 casos é: 2.19
# O Desvio Absoluto de Recuperados a cada 100 casos é: 21.47
# O Desvio Absoluto de confirmados na última semana é: 113496.88
# O Desvio Absoluto da % de aumentos em uma semana é: 12.01

# %% [markdown]
# # Correlação
# ---

# %%
corr = covid[["Confirmed","Deaths","Recovered","Active","Deaths / 100 Cases","Recovered / 100 Cases",
       "Confirmed last week","1 week % increase"]].corr()
corr
# Out:
#                        Confirmed    Deaths  Recovered    Active  \
# Confirmed               1.000000  0.934698   0.906377  0.927018
# Deaths                  0.934698  1.000000   0.832098  0.871586
# Recovered               0.906377  0.832098   1.000000  0.682103
# Active                  0.927018  0.871586   0.682103  1.000000
# Deaths / 100 Cases      0.063550  0.251565   0.048438  0.054380
# Recovered / 100 Cases  -0.064815 -0.114529   0.026610 -0.132618
# Confirmed last week     0.999127  0.939082   0.899312  0.931459
# 1 week % increase      -0.010161 -0.034708  -0.013697 -0.003752
#
#                        Deaths / 100 Cases  Recovered / 100 Cases  \
# Confirmed                        0.063550              -0.064815
# Deaths                           0.251565              -0.114529
# Recovered                        0.048438               0.026610
# Active                           0.054380              -0.132618
# ...

# %% [markdown]
# # Amplitude
# ---

# %%
# Amplitude(Confirmed)
Amplitude_Confirmed = covid["Confirmed"].max() - covid["Confirmed"].min()
print("A Amplitude de confirmados é: %.2f" %Variancia_Confirmed)

# Amplitude(Deaths)
Amplitude_Deaths = covid["Deaths"].max() - covid["Deaths"].min()
print("A Amplitude das mortes é: %.2f" %Amplitude_Deaths)

# Amplitude(Recovered)
Amplitude_Recovered = covid["Recovered"].max() - covid["Recovered"].min()
print("A Amplitude dos recuperados é: %.2f" %Amplitude_Recovered)

# Amplitude(Active)
Amplitude_Active = covid["Active"].max() - covid["Active"].min()
print("A Amplitude dos casos ativos é: %.2f" %Amplitude_Active)

# Amplitude(Deaths/100 Cases)
Amplitude_Deaths_100 = covid["Deaths / 100 Cases"].max() - covid["Deaths / 100 Cases"].min()
print("A Amplitude das mortes a cada 100 casos é: %.2f" %Amplitude_Deaths_100)

# Amplitude(Recovered/100 Cases)
Amplitude_Recovered_100 = covid["Recovered / 100 Cases"].max() - covid["Recovered / 100 Cases"].min()
print("A Amplitude dos recuperados a cada 100 casos é: %.2f" %Amplitude_Recovered_100)

# Amplitude(Deaths/100 Recovered)
Amplitude_Deaths_100 = covid["Deaths / 100 Recovered"].max() - covid["Deaths / 100 Recovered"].min()
print("A Amplitude de mortes a cada 100 casos é: %.2f" %Amplitude_Deaths_100)

# Amplitude(Confirmed last week)
Amplitude_Confirmed_last = covid["Confirmed last week"].max() - covid["Confirmed last week"].min()
print("A Amplitude de confirmados na última semana é: %.2f" %Amplitude_Confirmed_last)

# Amplitude(1 week % increase)
Amplitude_1_week = covid["1 week % increase"].max() - covid["1 week % increase"].min()
print("A Amplitude de aumentos em uma semana é: %.2f" %Amplitude_1_week)
# Out:
# A Amplitude de confirmados é: 146933198040.89
# A Amplitude das mortes é: 148011.00
# A Amplitude dos recuperados é: 1846641.00
# A Amplitude dos casos ativos é: 2816444.00
# A Amplitude das mortes a cada 100 casos é: 28.56
# A Amplitude dos recuperados a cada 100 casos é: 100.00
# A Amplitude de mortes a cada 100 casos é: inf
# A Amplitude de confirmados na última semana é: 3834667.00
# A Amplitude de aumentos em uma semana é: 230.16

# %% [markdown]
# # Boxplot
# ---

# %%
covid.boxplot(column=["Confirmed","Deaths","Recovered","Active","Deaths / 100 Cases","Recovered / 100 Cases","Confirmed last week","1 week % increase"])
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Gráficos:
# ## Visualização de Dados
# ---

# %% [markdown]
# Os gráficos serão retirados do dataframe (covid).

# %%
# Gráfico referente ao número de mortes nos países das Americas (Top6).

region1 = covid[covid["WHO Region"] == "Americas"]
aux1 = region1.sort_values(by=['Deaths'], ascending=False).head(6)
aux1
aux1.drop(columns=['New cases',"New deaths","New recovered","1 week change"])
# Out:
#     Country/Region  Confirmed  Deaths  Recovered   Active  Deaths / 100 Cases  \
# 173             US    4290259  148011    1325804  2816444                3.45
# 23          Brazil    2442375   87618    1846641   508116                3.59
# 111         Mexico     395489   44022     303810    47657               11.13
# 132           Peru     389717   18418     272547    98752                4.73
# 35           Chile     347923    9187     319954    18782                2.64
# 32          Canada     116458    8944          0   107514                7.68
#
#      Recovered / 100 Cases  Deaths / 100 Recovered  Confirmed last week  \
# 173                  30.90                   11.16              3834677
# 23                   75.61                    4.74              2118646
# 111                  76.82                   14.49               349396
# 132                  69.93                    6.76               357681
# ...

# %%
ax = sns.barplot(data=aux1, x="Deaths", y="Country/Region")
ax.set(xlabel="Número de mortes", ylabel="Países")
# Out:
# [Text(0.5, 0, 'Número de mortes'), Text(0, 0.5, 'Países')]

# %%
# Gráfico referente ao número de mortes nos países da Africa (Top 6).
region2 = covid[covid["WHO Region"] == "Africa"]
aux2 = region2.sort_values(by=['Deaths'], ascending=False).head(6)
aux2
aux2.drop(columns=['New cases',"New deaths","New recovered","1 week change"])
# Out:
#     Country/Region  Confirmed  Deaths  Recovered  Active  Deaths / 100 Cases  \
# 154   South Africa     452529    7067     274925  170537                1.56
# 2          Algeria      27973    1163      18837    7973                4.16
# 124        Nigeria      41180     860      18203   22117                2.09
# 31        Cameroon      17110     391      14539    2180                2.29
# 90           Kenya      17975     285       7833    9857                1.59
# 58        Ethiopia      14547     228       6386    7933                1.57
#
#      Recovered / 100 Cases  Deaths / 100 Recovered  Confirmed last week  \
# 154                  60.75                    2.57               373628
# 2                    67.34                    6.17                23691
# 124                  44.20                    4.72                37225
# 31                   84.97                    2.69                16157
# ...

# %%
sns.lineplot(data=aux2, x="Country/Region", y="Active",marker="o")
# Out:
# <AxesSubplot:xlabel='Country/Region', ylabel='Active'>

# %%
# Gráfico referente ao número de mortes nos países da Europa (Top 6).

region3 = covid[covid["WHO Region"] == "Europe"]
aux3 = region3.sort_values(by=['Deaths'], ascending=False).head(6)
aux3
aux3.drop(columns=['New cases',"New deaths","New recovered","1 week change"])
# Out:
#      Country/Region  Confirmed  Deaths  Recovered  Active  Deaths / 100 Cases  \
# 177  United Kingdom     301708   45844       1437  254427               15.19
# 85            Italy     246286   35112     198593   12581               14.26
# 61           France     220352   30212      81212  108928               13.71
# 157           Spain     272421   28432     150376   93613               10.44
# 138          Russia     816680   13334     602249  201097                1.63
# 16          Belgium      66428    9822      17452   39154               14.79
#
#      Recovered / 100 Cases  Deaths / 100 Recovered  Confirmed last week  \
# 177                   0.48                 3190.26               296944
# 85                   80.64                   17.68               244624
# 61                   36.86                   37.20               214023
# 157                  55.20                   18.91               264836
# ...

# %%
# Gráfico de correlação
x = aux3[["Deaths / 100 Cases","Recovered / 100 Cases","Deaths / 100 Recovered"]].corr()
sns.heatmap(x, annot=True)
# Out:
# <AxesSubplot:>

# %%
# Gráfico referente ao número de casos confirmados nos países da Western Pacific (Top 6).
region4 = covid[covid["WHO Region"] == "Western Pacific"]
aux4 = region4.sort_values(by=['Deaths'], ascending=False).head(6)
aux4
aux4.drop(columns=['New cases',"New deaths","New recovered","1 week change"])
# Out:
#     Country/Region  Confirmed  Deaths  Recovered  Active  Deaths / 100 Cases  \
# 36           China      86783    4656      78869    3258                5.37
# 133    Philippines      82040    1945      26446   53649                2.37
# 87           Japan      31142     998      21970    8174                3.20
# 155    South Korea      14203     300      13007     896                2.11
# 8        Australia      15303     167       9311    5825                1.09
# 105       Malaysia       8904     124       8601     179                1.39
#
#      Recovered / 100 Cases  Deaths / 100 Recovered  Confirmed last week  \
# 36                   90.88                    5.90                85622
# 133                  32.24                    7.35                68898
# 87                   70.55                    4.54                25706
# 155                  91.58                    2.31                13816
# ...

# %%
y = aux4.groupby("Country/Region").sum()

y.plot.pie(y="Confirmed")
# Out:
# <AxesSubplot:ylabel='Confirmed'>

# %% [markdown]
# # Limpeza e transformações
# ---

# %% [markdown]
# ### 1) Quais colunas precisaram de limpeza ou transformação?
#
# As colunas "New cases","New deaths","New recovered" e "1 week change" foram retiradas.
# Para os gráficos retiramos partes do DataFrame e separamos por regiões para melhorar a vizualização.

# %% [markdown]
# ### 2) Que métodos foram utilizados nas colunas citadas na pergunta anterior?
#
# Excluimos as colunas através do drop() , porque não usariamos os dados devido o crescimento de novos casos diariamente.
# Separamos as regiões utilizando covid[["WHO Region"] == "Nome_da_região"] e adicionamos a uma variável para criar uma lista menor.
# Ordenamos em ordem descrecente utilizando "ascending=False" e selecionamos as seis primeiras linhas usando ".head(6)".

# %% [markdown]
# # Agrupamentos
# ---

# %%
#Recuperados a cada 100 casos e Mortes a cada 100 casos.
df = covid[["Country/Region","Recovered / 100 Cases","Deaths / 100 Cases","WHO Region"]]
dfnovo = covid[["Recovered / 100 Cases","Deaths / 100 Cases"]]
#Este DataFrame(dfnovo) será usado no Kmeans, logo não poderá conter Strings(países).
df
# Out:
#          Country/Region  Recovered / 100 Cases  Deaths / 100 Cases  \
# 0           Afghanistan                  69.49                3.50
# 1               Albania                  56.25                2.95
# 2               Algeria                  67.34                4.16
# 3               Andorra                  88.53                5.73
# 4                Angola                  25.47                4.32
# ..                  ...                    ...                 ...
# 182  West Bank and Gaza                  35.33                0.73
# 183      Western Sahara                  80.00               10.00
# 184               Yemen                  49.26               28.56
# 185              Zambia                  61.84                3.08
# 186            Zimbabwe                  20.04                1.33
#
#                 WHO Region
# 0    Eastern Mediterranean
# 1                   Europe
# 2                   Africa
# 3                   Europe
# ...

# %%
sns.scatterplot(data=df,x="Deaths / 100 Cases",y="Recovered / 100 Cases");
#Como a dispersão acontece mais próxima ao eixo X , isso significas que são recuparadas 
# mais pessoas do que pessoas morrem, ambos a cada 100 casos.

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=7)
kmeans.fit(dfnovo)
# Out:
# KMeans(n_clusters=7)

# %%
sns.scatterplot(data=df,x="Deaths / 100 Cases",y="Recovered / 100 Cases", hue=kmeans.labels_);

# %%
finalk = df[kmeans.labels_== 1]
finalk
# Out:
#             Country/Region  Recovered / 100 Cases  Deaths / 100 Cases  \
# 3                  Andorra                  88.53                5.73
# 9                  Austria                  88.75                3.47
# 12                 Bahrain                  91.46                0.36
# 14                Barbados                  85.45                6.36
# 15                 Belarus                  89.95                0.80
# 19                  Bhutan                  86.87                0.00
# 24                  Brunei                  97.87                2.13
# 31                Cameroon                  84.97                2.29
# 34                    Chad                  87.85                8.13
# 35                   Chile                  91.96                2.64
# 36                   China                  90.88                5.37
# 38                 Comoros                  92.66                1.98
# ...

# %%
pd.value_counts(finalk["WHO Region"])
# Out:
# Europe                   19
# Western Pacific           9
# Africa                    9
# Americas                  8
# Eastern Mediterranean     8
# South-East Asia           2
# Name: WHO Region, dtype: int64

# %% [markdown]
# ### 1) Algum padrão foi descoberto? Cite algumas descobertas que chamaram atenção.

# %% [markdown]
# >Ao utilizar o Kmeans no gráfico de dispersão foi perceptível que a chance de mortes é menor que a chance de recuperados, ambos a cada 100 casos.

# %% [markdown]
# ### 2) Alguma nova pergunta foi descoberta ao analisar os diferentes agrupamentos? Se sim, cite quais foram as perguntas.

# %% [markdown]
# >Nos países que houveram mais recuperados e menos mortos ambos a cada 100 casos, quantos deles são do mesma Região ?
